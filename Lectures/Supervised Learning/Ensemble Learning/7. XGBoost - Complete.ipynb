# %% [markdown]
# # XGBoost
#
# Let's learn about a very popular package for gradient boosting called `XGBoost`.
#
# ## What we will accomplish
#
# In this notebook we will:
# - Introduce the `XGBoost` package and point to the package installation process,
# - Discuss what `XGBoost` is and why we use it over `sklearn` and
# - Show how to implement gradient boosting regression in `XGBoost`:
#     - Demonstrate `XGBoost` early stopping.

# %%
## For data handling
import pandas as pd
import numpy as np

## For plotting
import matplotlib.pyplot as plt
from seaborn import set_style

## This sets the plot style
## to have a grid on a white background
set_style("whitegrid")

# %% [markdown]
# ## Gradient boosting reminder
#
# In the previous notebook we learned what gradient boosting was and demonstrated how to implement it using `sklearn`'s `GradientBoostingRegressor` model object. Recall that this technique is a boosting approach where we iteratively train weak learners by training on the previous learner's residuals.
#
# ## What is `XGBoost`?
#
# While we implemented this algorithm using `sklearn`, another very popular package for gradient boosting is `XGBoost` which stands for eXtreme Gradient Boosting. This particular package is often utilized in winning data science competitions, which likely led to its increase in popularity.
#
# #### Installing `XGBoost`
#
# A quick note! You likely do not have `XGBoost` already installed on your computer (at least I did not prior to writing this notebook). If you have used `pip` to install python packages before you can install `XGBoost` using the command here, <a href="https://xgboost.readthedocs.io/en/latest/install.html#python">https://xgboost.readthedocs.io/en/latest/install.html#python</a>. If you use `conda` to install packages this link should help, <a href="https://anaconda.org/conda-forge/xgboost">https://anaconda.org/conda-forge/xgboost</a>.
#
# <i>Note: When I installed `XGBoost` on my machine it did not work at first, I had to install another piece of softward onto my MacBook before it would work. Follow the documentation from `XGBoost`, it worked for me.</i>
#
# <i>Also Note: If you are running a Mac with an M1 chip the standard installation instructions may not work for you. In that case you should perform a web search to find the relevant instructions.</i>
#
# ### Why `XGBoost`?
#
# Why do so many people like using `XGBoost` over `sklearn`'s `GradientBoostingRegressor` and `GradientBoostingClassifier`? In comparison to `sklearn`'s implementation `XGBoost`'s code for fitting gradient boosting models is much faster and tends to perform better than `sklearn`. It even offers the capability for your model to be trained in parallel, which `sklearn` does not currently offer for gradient boosting.
#
# ## Implementing gradient boosting regression in `XGBoost`
#
# With this motivation in mind, let's learn how to implement the same regression functionality we did with `sklearn` in the previous notebook. We will provide information on how to run gradient boosting classification and expand on the `XGBoost` syntax in the homework.

# %%
## First make our data set
np.random.seed(220)
X = np.linspace(-2,2,200)

y = X**2 + np.random.randn(200)

## Visualize the training data
plt.figure(figsize=(8,6))
plt.scatter(X,y)
plt.xlabel("$X$", fontsize=16)
plt.ylabel("$y$", fontsize=16)
plt.show()

# %% [markdown]
# One way to make a gradient boosting regressor in `XGBoost` is to use `XGBRegressor`, <a href="https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.XGBRegressor">https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.XGBRegressor</a>.

# %%
## import xgboost
import xgboost

# %%
## Let's recreate our learning_rate comparison

### Create an XGBRegressor object
### learning_rate=.1, max_depth=1, n_estimators=10
xgb_reg1 = xgboost.XGBRegressor(learning_rate=.1,
                                   max_depth=1,
                                   n_estimators=10)


## fit it
xgb_reg1.fit(X.reshape(-1,1), 
                y)

### Create an XGBRegressor object
### learning_rate=1, max_depth=1, n_estimators=10
xgb_reg2 = xgboost.XGBRegressor(learning_rate=1,
                                   max_depth=1,
                                   n_estimators=10)


## fit it
xgb_reg2.fit(X.reshape(-1,1), 
                y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=1, max_delta_step=0,
#              max_depth=1, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=10, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
fig,ax = plt.subplots(1,2,figsize=(20,8))

ax[0].scatter(X,y,label='Training Points')
ax[0].plot(X, xgb_reg1.predict(X.reshape(-1,1)), 'k',label="Prediction")
ax[0].set_title("learning_rate=0.1", fontsize=18)
ax[0].legend(fontsize=14)
ax[0].set_xlabel("$X$", fontsize=16)
ax[0].set_ylabel("$y$", fontsize=16)

ax[1].scatter(X,y,label='Training Points')
ax[1].plot(X, xgb_reg2.predict(X.reshape(-1,1)), 'k',label="Prediction")
ax[1].set_title("learning_rate=1", fontsize=18)
ax[1].legend(fontsize=14)
ax[1].set_xlabel("$X$", fontsize=16)
ax[1].set_ylabel("$y$", fontsize=16)

plt.show()

# %% [markdown]
# A nice feature of `xgboost`'s model is that it automatically records the performance at each training step on a validation set, provided we give the model the validation set.

# %%
## Here I will generate a validation set because the data are randomly generated
## in practice you would need to split the data
X_val = np.linspace(-2,2,200)
y_val = X_val**2 + np.random.randn(200)

# %%
## make an XGBRegressor object
## n_estimators = 500, max_depth = 1, learning_rate = .1
xgb_reg = xgboost.XGBRegressor(n_estimators=500,
                          max_depth=1,
                          learning_rate=.1)

## fit the model, including an eval_set
xgb_reg.fit(X.reshape(-1,1), y, eval_set=[(X_val.reshape(-1,1), y_val)])
# Out:
# [0]	validation_0-rmse:1.77179
# [1]	validation_0-rmse:1.71867
# [2]	validation_0-rmse:1.66455
# [3]	validation_0-rmse:1.62196
# [4]	validation_0-rmse:1.57879
# [5]	validation_0-rmse:1.54459
# [6]	validation_0-rmse:1.50800
# [7]	validation_0-rmse:1.48094
# [8]	validation_0-rmse:1.45219
# [9]	validation_0-rmse:1.43014
# [10]	validation_0-rmse:1.40503
# [11]	validation_0-rmse:1.38715
# [12]	validation_0-rmse:1.36746
# [13]	validation_0-rmse:1.35279
# [14]	validation_0-rmse:1.33496
# [15]	validation_0-rmse:1.32275
# [16]	validation_0-rmse:1.30585
# [17]	validation_0-rmse:1.29586
# [18]	validation_0-rmse:1.28377
# [19]	validation_0-rmse:1.27520
# [20]	validation_0-rmse:1.26043
# [21]	validation_0-rmse:1.25324
# [22]	validation_0-rmse:1.24013
# [23]	validation_0-rmse:1.23483
# [24]	validation_0-rmse:1.22628
# [25]	validation_0-rmse:1.22111
# [26]	validation_0-rmse:1.21005
# [27]	validation_0-rmse:1.20554
# [28]	validation_0-rmse:1.19881
# [29]	validation_0-rmse:1.19473
# [30]	validation_0-rmse:1.18531
# [31]	validation_0-rmse:1.18161
# [32]	validation_0-rmse:1.17501
# [33]	validation_0-rmse:1.17163
# [34]	validation_0-rmse:1.16668
# [35]	validation_0-rmse:1.16390
# [36]	validation_0-rmse:1.15812
# [37]	validation_0-rmse:1.15539
# [38]	validation_0-rmse:1.15130
# [39]	validation_0-rmse:1.15047
# [40]	validation_0-rmse:1.14517
# [41]	validation_0-rmse:1.14319
# [42]	validation_0-rmse:1.13733
# [43]	validation_0-rmse:1.13670
# [44]	validation_0-rmse:1.13227
# [45]	validation_0-rmse:1.13183
# [46]	validation_0-rmse:1.12879
# [47]	validation_0-rmse:1.12749
# [48]	validation_0-rmse:1.12342
# [49]	validation_0-rmse:1.12057
# [50]	validation_0-rmse:1.12048
# [51]	validation_0-rmse:1.11666
# [52]	validation_0-rmse:1.11667
# [53]	validation_0-rmse:1.11315
# [54]	validation_0-rmse:1.11216
# [55]	validation_0-rmse:1.10986
# [56]	validation_0-rmse:1.10998
# [57]	validation_0-rmse:1.10685
# [58]	validation_0-rmse:1.10704
# [59]	validation_0-rmse:1.10414
# [60]	validation_0-rmse:1.10213
# [61]	validation_0-rmse:1.09904
# [62]	validation_0-rmse:1.09929
# [63]	validation_0-rmse:1.09675
# [64]	validation_0-rmse:1.09705
# [65]	validation_0-rmse:1.09542
# [66]	validation_0-rmse:1.09377
# [67]	validation_0-rmse:1.09148
# [68]	validation_0-rmse:1.09178
# [69]	validation_0-rmse:1.08970
# [70]	validation_0-rmse:1.09004
# [71]	validation_0-rmse:1.08788
# [72]	validation_0-rmse:1.08751
# [73]	validation_0-rmse:1.08791
# [74]	validation_0-rmse:1.08577
# [75]	validation_0-rmse:1.08454
# [76]	validation_0-rmse:1.08494
# [77]	validation_0-rmse:1.08302
# [78]	validation_0-rmse:1.08175
# [79]	validation_0-rmse:1.08218
# [80]	validation_0-rmse:1.08032
# [81]	validation_0-rmse:1.08080
# [82]	validation_0-rmse:1.07919
# [83]	validation_0-rmse:1.07813
# [84]	validation_0-rmse:1.07715
# [85]	validation_0-rmse:1.07760
# [86]	validation_0-rmse:1.07593
# [87]	validation_0-rmse:1.07640
# [88]	validation_0-rmse:1.07482
# [89]	validation_0-rmse:1.07529
# [90]	validation_0-rmse:1.07379
# [91]	validation_0-rmse:1.07372
# [92]	validation_0-rmse:1.07217
# [93]	validation_0-rmse:1.07264
# [94]	validation_0-rmse:1.07126
# [95]	validation_0-rmse:1.07044
# [96]	validation_0-rmse:1.07092
# [97]	validation_0-rmse:1.06958
# [98]	validation_0-rmse:1.07005
# [99]	validation_0-rmse:1.06879
# [100]	validation_0-rmse:1.06813
# [101]	validation_0-rmse:1.06860
# [102]	validation_0-rmse:1.06746
# [103]	validation_0-rmse:1.06677
# [104]	validation_0-rmse:1.06710
# [105]	validation_0-rmse:1.06758
# [106]	validation_0-rmse:1.06645
# [107]	validation_0-rmse:1.06643
# [108]	validation_0-rmse:1.06583
# [109]	validation_0-rmse:1.06618
# [110]	validation_0-rmse:1.06516
# [111]	validation_0-rmse:1.06563
# [112]	validation_0-rmse:1.06597
# [113]	validation_0-rmse:1.06542
# [114]	validation_0-rmse:1.06505
# [115]	validation_0-rmse:1.06410
# [116]	validation_0-rmse:1.06456
# [117]	validation_0-rmse:1.06491
# [118]	validation_0-rmse:1.06398
# [119]	validation_0-rmse:1.06402
# [120]	validation_0-rmse:1.06448
# [121]	validation_0-rmse:1.06398
# [122]	validation_0-rmse:1.06432
# [123]	validation_0-rmse:1.06344
# [124]	validation_0-rmse:1.06390
# [125]	validation_0-rmse:1.06360
# [126]	validation_0-rmse:1.06275
# [127]	validation_0-rmse:1.06309
# [128]	validation_0-rmse:1.06265
# [129]	validation_0-rmse:1.06309
# [130]	validation_0-rmse:1.06231
# [131]	validation_0-rmse:1.06275
# [132]	validation_0-rmse:1.06308
# [133]	validation_0-rmse:1.06267
# [134]	validation_0-rmse:1.06241
# [135]	validation_0-rmse:1.06274
# [136]	validation_0-rmse:1.06207
# [137]	validation_0-rmse:1.06250
# [138]	validation_0-rmse:1.06167
# [139]	validation_0-rmse:1.06128
# [140]	validation_0-rmse:1.06160
# [141]	validation_0-rmse:1.06090
# [142]	validation_0-rmse:1.06133
# [143]	validation_0-rmse:1.06080
# [144]	validation_0-rmse:1.06059
# [145]	validation_0-rmse:1.06090
# [146]	validation_0-rmse:1.06029
# [147]	validation_0-rmse:1.06060
# [148]	validation_0-rmse:1.06001
# [149]	validation_0-rmse:1.06042
# [150]	validation_0-rmse:1.05972
# [151]	validation_0-rmse:1.06003
# [152]	validation_0-rmse:1.05946
# [153]	validation_0-rmse:1.05977
# [154]	validation_0-rmse:1.05989
# [155]	validation_0-rmse:1.05924
# [156]	validation_0-rmse:1.05964
# [157]	validation_0-rmse:1.05901
# [158]	validation_0-rmse:1.05847
# [159]	validation_0-rmse:1.05878
# [160]	validation_0-rmse:1.05860
# [161]	validation_0-rmse:1.05899
# [162]	validation_0-rmse:1.05841
# [163]	validation_0-rmse:1.05788
# [164]	validation_0-rmse:1.05819
# [165]	validation_0-rmse:1.05857
# [166]	validation_0-rmse:1.05805
# [167]	validation_0-rmse:1.05836
# [168]	validation_0-rmse:1.05781
# [169]	validation_0-rmse:1.05819
# [170]	validation_0-rmse:1.05769
# [171]	validation_0-rmse:1.05799
# [172]	validation_0-rmse:1.05747
# [173]	validation_0-rmse:1.05731
# [174]	validation_0-rmse:1.05760
# [175]	validation_0-rmse:1.05708
# [176]	validation_0-rmse:1.05737
# [177]	validation_0-rmse:1.05687
# [178]	validation_0-rmse:1.05724
# [179]	validation_0-rmse:1.05671
# [180]	validation_0-rmse:1.05700
# [181]	validation_0-rmse:1.05652
# [182]	validation_0-rmse:1.05680
# [183]	validation_0-rmse:1.05634
# [184]	validation_0-rmse:1.05670
# [185]	validation_0-rmse:1.05698
# [186]	validation_0-rmse:1.05652
# [187]	validation_0-rmse:1.05661
# [188]	validation_0-rmse:1.05610
# [189]	validation_0-rmse:1.05638
# [190]	validation_0-rmse:1.05594
# [191]	validation_0-rmse:1.05622
# [192]	validation_0-rmse:1.05657
# [193]	validation_0-rmse:1.05607
# [194]	validation_0-rmse:1.05594
# [195]	validation_0-rmse:1.05551
# [196]	validation_0-rmse:1.05579
# [197]	validation_0-rmse:1.05537
# [198]	validation_0-rmse:1.05565
# [199]	validation_0-rmse:1.05599
# [200]	validation_0-rmse:1.05535
# [201]	validation_0-rmse:1.05495
# [202]	validation_0-rmse:1.05522
# [203]	validation_0-rmse:1.05533
# [204]	validation_0-rmse:1.05519
# [205]	validation_0-rmse:1.05552
# [206]	validation_0-rmse:1.05505
# [207]	validation_0-rmse:1.05494
# [208]	validation_0-rmse:1.05481
# [209]	validation_0-rmse:1.05504
# [210]	validation_0-rmse:1.05492
# [211]	validation_0-rmse:1.05504
# [212]	validation_0-rmse:1.05530
# [213]	validation_0-rmse:1.05488
# [214]	validation_0-rmse:1.05476
# [215]	validation_0-rmse:1.05499
# [216]	validation_0-rmse:1.05525
# [217]	validation_0-rmse:1.05485
# [218]	validation_0-rmse:1.05473
# [219]	validation_0-rmse:1.05485
# [220]	validation_0-rmse:1.05442
# [221]	validation_0-rmse:1.05476
# [222]	validation_0-rmse:1.05463
# [223]	validation_0-rmse:1.05486
# [224]	validation_0-rmse:1.05474
# [225]	validation_0-rmse:1.05496
# [226]	validation_0-rmse:1.05485
# [227]	validation_0-rmse:1.05496
# [228]	validation_0-rmse:1.05522
# [229]	validation_0-rmse:1.05483
# [230]	validation_0-rmse:1.05472
# [231]	validation_0-rmse:1.05494
# [232]	validation_0-rmse:1.05520
# [233]	validation_0-rmse:1.05482
# [234]	validation_0-rmse:1.05471
# [235]	validation_0-rmse:1.05483
# [236]	validation_0-rmse:1.05441
# [237]	validation_0-rmse:1.05474
# [238]	validation_0-rmse:1.05462
# [239]	validation_0-rmse:1.05484
# [240]	validation_0-rmse:1.05473
# [241]	validation_0-rmse:1.05495
# [242]	validation_0-rmse:1.05520
# [243]	validation_0-rmse:1.05509
# [244]	validation_0-rmse:1.05521
# [245]	validation_0-rmse:1.05502
# [246]	validation_0-rmse:1.05491
# [247]	validation_0-rmse:1.05513
# [248]	validation_0-rmse:1.05503
# [249]	validation_0-rmse:1.05524
# [250]	validation_0-rmse:1.05514
# [251]	validation_0-rmse:1.05526
# [252]	validation_0-rmse:1.05486
# [253]	validation_0-rmse:1.05518
# [254]	validation_0-rmse:1.05507
# [255]	validation_0-rmse:1.05529
# [256]	validation_0-rmse:1.05518
# [257]	validation_0-rmse:1.05530
# [258]	validation_0-rmse:1.05554
# [259]	validation_0-rmse:1.05517
# [260]	validation_0-rmse:1.05508
# [261]	validation_0-rmse:1.05497
# [262]	validation_0-rmse:1.05518
# [263]	validation_0-rmse:1.05507
# [264]	validation_0-rmse:1.05529
# [265]	validation_0-rmse:1.05520
# [266]	validation_0-rmse:1.05551
# [267]	validation_0-rmse:1.05512
# [268]	validation_0-rmse:1.05540
# [269]	validation_0-rmse:1.05564
# [270]	validation_0-rmse:1.05529
# [271]	validation_0-rmse:1.05569
# [272]	validation_0-rmse:1.05529
# [273]	validation_0-rmse:1.05557
# [274]	validation_0-rmse:1.05549
# [275]	validation_0-rmse:1.05557
# [276]	validation_0-rmse:1.05546
# [277]	validation_0-rmse:1.05557
# [278]	validation_0-rmse:1.05549
# [279]	validation_0-rmse:1.05557
# [280]	validation_0-rmse:1.05547
# [281]	validation_0-rmse:1.05568
# [282]	validation_0-rmse:1.05533
# [283]	validation_0-rmse:1.05557
# [284]	validation_0-rmse:1.05547
# [285]	validation_0-rmse:1.05568
# [286]	validation_0-rmse:1.05558
# [287]	validation_0-rmse:1.05569
# [288]	validation_0-rmse:1.05561
# [289]	validation_0-rmse:1.05593
# [290]	validation_0-rmse:1.05555
# [291]	validation_0-rmse:1.05582
# [292]	validation_0-rmse:1.05574
# [293]	validation_0-rmse:1.05582
# [294]	validation_0-rmse:1.05574
# [295]	validation_0-rmse:1.05605
# [296]	validation_0-rmse:1.05567
# [297]	validation_0-rmse:1.05594
# [298]	validation_0-rmse:1.05586
# [299]	validation_0-rmse:1.05594
# [300]	validation_0-rmse:1.05584
# [301]	validation_0-rmse:1.05605
# [302]	validation_0-rmse:1.05571
# [303]	validation_0-rmse:1.05611
# [304]	validation_0-rmse:1.05583
# [305]	validation_0-rmse:1.05607
# [306]	validation_0-rmse:1.05574
# [307]	validation_0-rmse:1.05613
# [308]	validation_0-rmse:1.05603
# [309]	validation_0-rmse:1.05615
# [310]	validation_0-rmse:1.05607
# [311]	validation_0-rmse:1.05638
# [312]	validation_0-rmse:1.05601
# [313]	validation_0-rmse:1.05627
# [314]	validation_0-rmse:1.05620
# [315]	validation_0-rmse:1.05628
# [316]	validation_0-rmse:1.05618
# [317]	validation_0-rmse:1.05639
# [318]	validation_0-rmse:1.05629
# [319]	validation_0-rmse:1.05649
# [320]	validation_0-rmse:1.05617
# [321]	validation_0-rmse:1.05641
# [322]	validation_0-rmse:1.05634
# [323]	validation_0-rmse:1.05665
# [324]	validation_0-rmse:1.05628
# [325]	validation_0-rmse:1.05655
# [326]	validation_0-rmse:1.05648
# [327]	validation_0-rmse:1.05655
# [328]	validation_0-rmse:1.05646
# [329]	validation_0-rmse:1.05657
# [330]	validation_0-rmse:1.05650
# [331]	validation_0-rmse:1.05680
# [332]	validation_0-rmse:1.05644
# [333]	validation_0-rmse:1.05682
# [334]	validation_0-rmse:1.05648
# [335]	validation_0-rmse:1.05640
# [336]	validation_0-rmse:1.05663
# [337]	validation_0-rmse:1.05635
# [338]	validation_0-rmse:1.05673
# [339]	validation_0-rmse:1.05640
# [340]	validation_0-rmse:1.05666
# [341]	validation_0-rmse:1.05659
# [342]	validation_0-rmse:1.05666
# [343]	validation_0-rmse:1.05657
# [344]	validation_0-rmse:1.05677
# [345]	validation_0-rmse:1.05672
# [346]	validation_0-rmse:1.05681
# [347]	validation_0-rmse:1.05672
# [348]	validation_0-rmse:1.05683
# [349]	validation_0-rmse:1.05676
# [350]	validation_0-rmse:1.05705
# [351]	validation_0-rmse:1.05669
# [352]	validation_0-rmse:1.05706
# [353]	validation_0-rmse:1.05679
# [354]	validation_0-rmse:1.05705
# [355]	validation_0-rmse:1.05698
# [356]	validation_0-rmse:1.05706
# [357]	validation_0-rmse:1.05699
# [358]	validation_0-rmse:1.05708
# [359]	validation_0-rmse:1.05702
# [360]	validation_0-rmse:1.05684
# [361]	validation_0-rmse:1.05675
# [362]	validation_0-rmse:1.05695
# [363]	validation_0-rmse:1.05691
# [364]	validation_0-rmse:1.05700
# [365]	validation_0-rmse:1.05694
# [366]	validation_0-rmse:1.05703
# [367]	validation_0-rmse:1.05693
# [368]	validation_0-rmse:1.05713
# [369]	validation_0-rmse:1.05707
# [370]	validation_0-rmse:1.05716
# [371]	validation_0-rmse:1.05710
# [372]	validation_0-rmse:1.05693
# [373]	validation_0-rmse:1.05684
# [374]	validation_0-rmse:1.05695
# [375]	validation_0-rmse:1.05688
# [376]	validation_0-rmse:1.05718
# [377]	validation_0-rmse:1.05682
# [378]	validation_0-rmse:1.05708
# [379]	validation_0-rmse:1.05701
# [380]	validation_0-rmse:1.05709
# [381]	validation_0-rmse:1.05702
# [382]	validation_0-rmse:1.05710
# [383]	validation_0-rmse:1.05701
# [384]	validation_0-rmse:1.05721
# [385]	validation_0-rmse:1.05717
# [386]	validation_0-rmse:1.05726
# [387]	validation_0-rmse:1.05720
# [388]	validation_0-rmse:1.05729
# [389]	validation_0-rmse:1.05723
# [390]	validation_0-rmse:1.05732
# [391]	validation_0-rmse:1.05723
# [392]	validation_0-rmse:1.05742
# [393]	validation_0-rmse:1.05736
# [394]	validation_0-rmse:1.05719
# [395]	validation_0-rmse:1.05689
# [396]	validation_0-rmse:1.05712
# [397]	validation_0-rmse:1.05749
# [398]	validation_0-rmse:1.05717
# [399]	validation_0-rmse:1.05711
# [400]	validation_0-rmse:1.05720
# [401]	validation_0-rmse:1.05711
# [402]	validation_0-rmse:1.05722
# [403]	validation_0-rmse:1.05716
# [404]	validation_0-rmse:1.05745
# [405]	validation_0-rmse:1.05713
# [406]	validation_0-rmse:1.05735
# [407]	validation_0-rmse:1.05705
# [408]	validation_0-rmse:1.05742
# [409]	validation_0-rmse:1.05716
# [410]	validation_0-rmse:1.05741
# [411]	validation_0-rmse:1.05735
# [412]	validation_0-rmse:1.05743
# [413]	validation_0-rmse:1.05737
# [414]	validation_0-rmse:1.05746
# [415]	validation_0-rmse:1.05737
# [416]	validation_0-rmse:1.05757
# [417]	validation_0-rmse:1.05751
# [418]	validation_0-rmse:1.05760
# [419]	validation_0-rmse:1.05754
# [420]	validation_0-rmse:1.05763
# [421]	validation_0-rmse:1.05757
# [422]	validation_0-rmse:1.05766
# [423]	validation_0-rmse:1.05758
# [424]	validation_0-rmse:1.05769
# [425]	validation_0-rmse:1.05762
# [426]	validation_0-rmse:1.05791
# [427]	validation_0-rmse:1.05757
# [428]	validation_0-rmse:1.05793
# [429]	validation_0-rmse:1.05763
# [430]	validation_0-rmse:1.05785
# [431]	validation_0-rmse:1.05756
# [432]	validation_0-rmse:1.05792
# [433]	validation_0-rmse:1.05767
# [434]	validation_0-rmse:1.05792
# [435]	validation_0-rmse:1.05785
# [436]	validation_0-rmse:1.05793
# [437]	validation_0-rmse:1.05787
# [438]	validation_0-rmse:1.05815
# [439]	validation_0-rmse:1.05782
# [440]	validation_0-rmse:1.05818
# [441]	validation_0-rmse:1.05788
# [442]	validation_0-rmse:1.05811
# [443]	validation_0-rmse:1.05807
# [444]	validation_0-rmse:1.05790
# [445]	validation_0-rmse:1.05814
# [446]	validation_0-rmse:1.05808
# [447]	validation_0-rmse:1.05816
# [448]	validation_0-rmse:1.05807
# [449]	validation_0-rmse:1.05827
# [450]	validation_0-rmse:1.05821
# [451]	validation_0-rmse:1.05830
# [452]	validation_0-rmse:1.05824
# [453]	validation_0-rmse:1.05833
# [454]	validation_0-rmse:1.05825
# [455]	validation_0-rmse:1.05844
# [456]	validation_0-rmse:1.05838
# [457]	validation_0-rmse:1.05847
# [458]	validation_0-rmse:1.05841
# [459]	validation_0-rmse:1.05825
# [460]	validation_0-rmse:1.05801
# [461]	validation_0-rmse:1.05844
# [462]	validation_0-rmse:1.05812
# [463]	validation_0-rmse:1.05808
# [464]	validation_0-rmse:1.05817
# [465]	validation_0-rmse:1.05812
# [466]	validation_0-rmse:1.05821
# [467]	validation_0-rmse:1.05816
# [468]	validation_0-rmse:1.05825
# [469]	validation_0-rmse:1.05816
# [470]	validation_0-rmse:1.05827
# [471]	validation_0-rmse:1.05821
# [472]	validation_0-rmse:1.05850
# [473]	validation_0-rmse:1.05844
# [474]	validation_0-rmse:1.05852
# [475]	validation_0-rmse:1.05844
# [476]	validation_0-rmse:1.05863
# [477]	validation_0-rmse:1.05858
# [478]	validation_0-rmse:1.05867
# [479]	validation_0-rmse:1.05861
# [480]	validation_0-rmse:1.05845
# [481]	validation_0-rmse:1.05842
# [482]	validation_0-rmse:1.05851
# [483]	validation_0-rmse:1.05843
# [484]	validation_0-rmse:1.05854
# [485]	validation_0-rmse:1.05848
# [486]	validation_0-rmse:1.05876
# [487]	validation_0-rmse:1.05844
# [488]	validation_0-rmse:1.05869
# [489]	validation_0-rmse:1.05863
# [490]	validation_0-rmse:1.05871
# [491]	validation_0-rmse:1.05863
# [492]	validation_0-rmse:1.05882
# [493]	validation_0-rmse:1.05876
# [494]	validation_0-rmse:1.05885
# [495]	validation_0-rmse:1.05880
# [496]	validation_0-rmse:1.05889
# [497]	validation_0-rmse:1.05883
# [498]	validation_0-rmse:1.05868
# [499]	validation_0-rmse:1.05831
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=1, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=500, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
## demonstrate .evals_result()
xgb_reg.evals_result()
# Out:
# {'validation_0': OrderedDict([('rmse',
#                [1.771788,
#                 1.718668,
#                 1.664546,
#                 1.621963,
#                 1.578791,
#                 1.544593,
#                 1.507999,
#                 1.480945,
#                 1.452195,
#                 1.43014,
#                 1.405029,
#                 1.387147,
#                 1.367456,
#                 1.352794,
#                 1.334959,
#                 1.322751,
#                 1.305848,
#                 1.29586,
#                 1.283767,
#                 1.275201,
#                 1.260429,
#                 1.253244,
#                 1.240126,
#                 1.234826,
#                 1.226277,
#                 1.221111,
#                 1.210045,
#                 1.205535,
#                 1.198814,
#                 1.194731,
#                 1.185305,
#                 1.181609,
#                 1.175006,
#                 1.171635,
#                 1.166678,
#                 1.163896,
#                 1.158117,
#                 1.155395,
#                 1.151297,
#                 1.150467,
#                 1.145171,
#                 1.14319,
#                 1.137329,
#                 1.136697,
#                 1.132274,
#                 1.131829,
#                 1.128791,
#                 1.127487,
#                 1.123419,
#                 1.120572,
#                 1.120481,
#                 1.116656,
#                 1.116667,
#                 1.113146,
#                 1.112157,
#                 1.109858,
#                 1.109981,
#                 1.106851,
#                 1.107043,
#                 1.10414,
#                 1.102134,
#                 1.099044,
#                 1.099293,
#                 1.096749,
#                 1.097052,
#                 1.095423,
#                 1.093772,
#                 1.09148,
#                 1.091784,
#                 1.089695,
#                 1.090036,
#                 1.087881,
#                 1.087511,
#                 1.087908,
#                 1.085774,
#                 1.084539,
#                 1.084944,
#                 1.083024,
#                 1.08175,
#                 1.08218,
#                 1.08032,
#                 1.080801,
#                 1.079186,
#                 1.078128,
#                 1.077147,
#                 1.077603,
#                 1.075934,
#                 1.076398,
#                 1.074819,
#                 1.075289,
#                 1.073794,
#                 1.073724,
#                 1.072168,
#                 1.072644,
#                 1.07126,
#                 1.07044,
#                 1.070916,
#                 1.069579,
#                 1.070055,
#                 1.06879,
#                 1.068126,
#                 1.068602,
#                 1.067456,
#                 1.066768,
#                 1.067104,
#                 1.067578,
#                 1.066449,
#                 1.066431,
#                 1.065834,
#                 1.066175,
#                 1.06516,
#                 1.065632,
#                 1.065975,
#                 1.065417,
#                 1.065048,
#                 1.064097,
#                 1.064564,
#                 1.064906,
#                 1.063983,
#                 1.064021,
#                 1.064476,
#                 1.063981,
#                 1.06432,
#                 1.063444,
#                 1.063896,
#                 1.063597,
#                 1.062752,
#                 1.063087,
#                 1.062646,
#                 1.063094,
#                 1.062309,
#                 1.062747,
#                 1.063079,
#                 1.062672,
#                 1.062411,
#                 1.062737,
#                 1.06207,
#                 1.062502,
#                 1.061666,
#                 1.06128,
#                 1.0616,
#                 1.0609,
#                 1.061326,
#                 1.060802,
#                 1.060589,
#                 1.060904,
#                 1.060291,
#                 1.060604,
#                 1.06001,
#                 1.060415,
#                 1.059717,
#                 1.06003,
#                 1.059459,
#                 1.05977,
#                 1.059891,
#                 1.059238,
#                 1.059636,
#                 1.059012,
#                 1.058469,
#                 1.05878,
#                 1.058598,
#                 1.058985,
#                 1.058413,
#                 1.057885,
#                 1.058193,
#                 1.058574,
#                 1.058053,
#                 1.058357,
#                 1.057814,
#                 1.05819,
#                 1.057686,
#                 1.057988,
#                 1.05747,
#                 1.057312,
#                 1.057603,
#                 1.057084,
#                 1.057374,
#                 1.056871,
#                 1.057239,
#                 1.056712,
#                 1.057001,
#                 1.056517,
#                 1.056804,
#                 1.056335,
#                 1.056698,
#                 1.056981,
#                 1.05652,
#                 1.056614,
#                 1.056101,
#                 1.056383,
#                 1.055942,
#                 1.056222,
#                 1.05657,
#                 1.056073,
#                 1.055944,
#                 1.055515,
#                 1.055792,
#                 1.055375,
#                 1.055649,
#                 1.05599,
#                 1.055348,
#                 1.05495,
#                 1.055223,
#                 1.055333,
#                 1.055192,
#                 1.055523,
#                 1.055049,
#                 1.054936,
#                 1.05481,
#                 1.05504,
#                 1.054916,
#                 1.055036,
#                 1.055296,
#                 1.054881,
#                 1.054759,
#                 1.054989,
#                 1.055247,
#                 1.054846,
#                 1.054726,
#                 1.054846,
#                 1.05442,
#                 1.054756,
#                 1.054634,
#                 1.054861,
#                 1.05474,
#                 1.054965,
#                 1.054846,
#                 1.054965,
#                 1.055222,
#                 1.054834,
#                 1.054718,
#                 1.054943,
#                 1.055198,
#                 1.054822,
#                 1.054707,
#                 1.054827,
#                 1.054413,
#                 1.054738,
#                 1.054622,
#                 1.054844,
#                 1.05473,
#                 1.05495,
#                 1.055203,
#                 1.05509,
#                 1.055209,
#                 1.05502,
#                 1.054911,
#                 1.055133,
#                 1.055025,
#                 1.055244,
#                 1.055136,
#                 1.055255,
#                 1.05486,
#                 1.055178,
#                 1.055069,
#                 1.055285,
#                 1.055178,
#                 1.055295,
#                 1.055541,
#                 1.055174,
#                 1.055077,
#                 1.054969,
#                 1.055181,
#                 1.055074,
#                 1.055285,
#                 1.055205,
#                 1.055514,
#                 1.055124,
#                 1.055402,
#                 1.055645,
#                 1.055289,
#                 1.055687,
#                 1.055294,
#                 1.055567,
#                 1.055486,
#                 1.055566,
#                 1.055459,
#                 1.055575,
#                 1.055493,
#                 1.055574,
#                 1.055468,
#                 1.055677,
#                 1.055331,
#                 1.055575,
#                 1.055472,
#                 1.05568,
#                 1.055579,
#                 1.055694,
#                 1.055615,
#                 1.055931,
#                 1.055546,
#                 1.055816,
#                 1.055737,
#                 1.055818,
#                 1.055741,
#                 1.056054,
#                 1.055673,
#                 1.055941,
#                 1.055864,
#                 1.055945,
#                 1.055843,
#                 1.05605,
#                 1.055714,
#                 1.056113,
#                 1.055827,
#                 1.056068,
#                 1.055736,
#                 1.056133,
#                 1.056034,
#                 1.056148,
#                 1.056073,
#                 1.056382,
#                 1.056008,
#                 1.056273,
#                 1.056198,
#                 1.056278,
#                 1.05618,
#                 1.056386,
#                 1.05629,
#                 1.056495,
#                 1.05617,
#                 1.05641,
#                 1.056339,
#                 1.056648,
#                 1.056283,
#                 1.056546,
#                 1.056475,
#                 1.056555,
#                 1.056459,
#                 1.056573,
#                 1.0565,
#                 1.056803,
#                 1.056438,
#                 1.056818,
#                 1.056483,
#                 1.056399,
#                 1.056629,
#                 1.056353,
#                 1.056732,
#                 1.056401,
#                 1.056659,
#                 1.056585,
#                 1.056665,
#                 1.056567,
#                 1.056767,
#                 1.05672,
#                 1.056811,
#                 1.056715,
#                 1.056827,
#                 1.056755,
#                 1.057051,
#                 1.056691,
#                 1.057063,
#                 1.056791,
#                 1.057047,
#                 1.056977,
#                 1.057057,
#                 1.056991,
#                 1.057084,
#                 1.057019,
#                 1.056843,
#                 1.056751,
#                 1.056952,
#                 1.056907,
#                 1.056999,
#                 1.056936,
#                 1.057028,
#                 1.056935,
#                 1.057134,
#                 1.05707,
#                 1.057161,
#                 1.057098,
#                 1.056927,
#                 1.056837,
#                 1.056949,
#                 1.05688,
#                 1.057176,
#                 1.056825,
#                 1.057079,
#                 1.057011,
#                 1.05709,
#                 1.057023,
#                 1.057102,
#                 1.057012,
#                 1.05721,
#                 1.057166,
#                 1.057258,
#                 1.057196,
#                 1.057287,
#                 1.057226,
#                 1.057317,
#                 1.057227,
#                 1.057421,
#                 1.057359,
#                 1.057192,
#                 1.056887,
#                 1.057122,
#                 1.057489,
#                 1.057168,
#                 1.057108,
#                 1.0572,
#                 1.057112,
#                 1.057223,
#                 1.057157,
#                 1.057451,
#                 1.057125,
#                 1.057352,
#                 1.057046,
#                 1.057418,
#                 1.05716,
#                 1.057413,
#                 1.057348,
#                 1.057427,
#                 1.057368,
#                 1.05746,
#                 1.057373,
#                 1.057568,
#                 1.057508,
#                 1.0576,
#                 1.05754,
#                 1.057631,
#                 1.057572,
#                 1.057663,
#                 1.057576,
#                 1.057686,
#                 1.05762,
#                 1.057909,
#                 1.057568,
#                 1.057933,
#                 1.057628,
#                 1.057853,
#                 1.057558,
#                 1.057919,
#                 1.057667,
#                 1.057916,
#                 1.057851,
#                 1.05793,
#                 1.057866,
#                 1.058153,
#                 1.057819,
#                 1.058176,
#                 1.057883,
#                 1.058106,
#                 1.058068,
#                 1.0579,
#                 1.058144,
#                 1.05808,
#                 1.058159,
#                 1.058073,
#                 1.058266,
#                 1.058209,
#                 1.058299,
#                 1.058242,
#                 1.058333,
#                 1.058247,
#                 1.058438,
#                 1.05838,
#                 1.05847,
#                 1.058413,
#                 1.058254,
#                 1.058007,
#                 1.058444,
#                 1.058122,
#                 1.058084,
#                 1.058174,
#                 1.05812,
#                 1.05821,
#                 1.058156,
#                 1.058246,
#                 1.058164,
#                 1.058273,
#                 1.058214,
#                 1.058503,
#                 1.058444,
#                 1.058522,
#                 1.058441,
#                 1.058632,
#                 1.058577,
#                 1.058667,
#                 1.058612,
#                 1.058455,
#                 1.058418,
#                 1.058508,
#                 1.058428,
#                 1.058536,
#                 1.058477,
#                 1.058761,
#                 1.058441,
#                 1.058688,
#                 1.058628,
#                 1.058706,
#                 1.058626,
#                 1.058816,
#                 1.058762,
#                 1.058851,
#                 1.058798,
#                 1.058887,
#                 1.058834,
#                 1.05868,
#                 1.058306])])}

# %%
## get the 'rmse'
xgb_reg.evals_result()['validation_0']['rmse']
# Out:
# [1.771788,
#  1.718668,
#  1.664546,
#  1.621963,
#  1.578791,
#  1.544593,
#  1.507999,
#  1.480945,
#  1.452195,
#  1.43014,
#  1.405029,
#  1.387147,
#  1.367456,
#  1.352794,
#  1.334959,
#  1.322751,
#  1.305848,
#  1.29586,
#  1.283767,
#  1.275201,
#  1.260429,
#  1.253244,
#  1.240126,
#  1.234826,
#  1.226277,
#  1.221111,
#  1.210045,
#  1.205535,
#  1.198814,
#  1.194731,
#  1.185305,
#  1.181609,
#  1.175006,
#  1.171635,
#  1.166678,
#  1.163896,
#  1.158117,
#  1.155395,
#  1.151297,
#  1.150467,
#  1.145171,
#  1.14319,
#  1.137329,
#  1.136697,
#  1.132274,
#  1.131829,
#  1.128791,
#  1.127487,
#  1.123419,
#  1.120572,
#  1.120481,
#  1.116656,
#  1.116667,
#  1.113146,
#  1.112157,
#  1.109858,
#  1.109981,
#  1.106851,
#  1.107043,
#  1.10414,
#  1.102134,
#  1.099044,
#  1.099293,
#  1.096749,
#  1.097052,
#  1.095423,
#  1.093772,
#  1.09148,
#  1.091784,
#  1.089695,
#  1.090036,
#  1.087881,
#  1.087511,
#  1.087908,
#  1.085774,
#  1.084539,
#  1.084944,
#  1.083024,
#  1.08175,
#  1.08218,
#  1.08032,
#  1.080801,
#  1.079186,
#  1.078128,
#  1.077147,
#  1.077603,
#  1.075934,
#  1.076398,
#  1.074819,
#  1.075289,
#  1.073794,
#  1.073724,
#  1.072168,
#  1.072644,
#  1.07126,
#  1.07044,
#  1.070916,
#  1.069579,
#  1.070055,
#  1.06879,
#  1.068126,
#  1.068602,
#  1.067456,
#  1.066768,
#  1.067104,
#  1.067578,
#  1.066449,
#  1.066431,
#  1.065834,
#  1.066175,
#  1.06516,
#  1.065632,
#  1.065975,
#  1.065417,
#  1.065048,
#  1.064097,
#  1.064564,
#  1.064906,
#  1.063983,
#  1.064021,
#  1.064476,
#  1.063981,
#  1.06432,
#  1.063444,
#  1.063896,
#  1.063597,
#  1.062752,
#  1.063087,
#  1.062646,
#  1.063094,
#  1.062309,
#  1.062747,
#  1.063079,
#  1.062672,
#  1.062411,
#  1.062737,
#  1.06207,
#  1.062502,
#  1.061666,
#  1.06128,
#  1.0616,
#  1.0609,
#  1.061326,
#  1.060802,
#  1.060589,
#  1.060904,
#  1.060291,
#  1.060604,
#  1.06001,
#  1.060415,
#  1.059717,
#  1.06003,
#  1.059459,
#  1.05977,
#  1.059891,
#  1.059238,
#  1.059636,
#  1.059012,
#  1.058469,
#  1.05878,
#  1.058598,
#  1.058985,
#  1.058413,
#  1.057885,
#  1.058193,
#  1.058574,
#  1.058053,
#  1.058357,
#  1.057814,
#  1.05819,
#  1.057686,
#  1.057988,
#  1.05747,
#  1.057312,
#  1.057603,
#  1.057084,
#  1.057374,
#  1.056871,
#  1.057239,
#  1.056712,
#  1.057001,
#  1.056517,
#  1.056804,
#  1.056335,
#  1.056698,
#  1.056981,
#  1.05652,
#  1.056614,
#  1.056101,
#  1.056383,
#  1.055942,
#  1.056222,
#  1.05657,
#  1.056073,
#  1.055944,
#  1.055515,
#  1.055792,
#  1.055375,
#  1.055649,
#  1.05599,
#  1.055348,
#  1.05495,
#  1.055223,
#  1.055333,
#  1.055192,
#  1.055523,
#  1.055049,
#  1.054936,
#  1.05481,
#  1.05504,
#  1.054916,
#  1.055036,
#  1.055296,
#  1.054881,
#  1.054759,
#  1.054989,
#  1.055247,
#  1.054846,
#  1.054726,
#  1.054846,
#  1.05442,
#  1.054756,
#  1.054634,
#  1.054861,
#  1.05474,
#  1.054965,
#  1.054846,
#  1.054965,
#  1.055222,
#  1.054834,
#  1.054718,
#  1.054943,
#  1.055198,
#  1.054822,
#  1.054707,
#  1.054827,
#  1.054413,
#  1.054738,
#  1.054622,
#  1.054844,
#  1.05473,
#  1.05495,
#  1.055203,
#  1.05509,
#  1.055209,
#  1.05502,
#  1.054911,
#  1.055133,
#  1.055025,
#  1.055244,
#  1.055136,
#  1.055255,
#  1.05486,
#  1.055178,
#  1.055069,
#  1.055285,
#  1.055178,
#  1.055295,
#  1.055541,
#  1.055174,
#  1.055077,
#  1.054969,
#  1.055181,
#  1.055074,
#  1.055285,
#  1.055205,
#  1.055514,
#  1.055124,
#  1.055402,
#  1.055645,
#  1.055289,
#  1.055687,
#  1.055294,
#  1.055567,
#  1.055486,
#  1.055566,
#  1.055459,
#  1.055575,
#  1.055493,
#  1.055574,
#  1.055468,
#  1.055677,
#  1.055331,
#  1.055575,
#  1.055472,
#  1.05568,
#  1.055579,
#  1.055694,
#  1.055615,
#  1.055931,
#  1.055546,
#  1.055816,
#  1.055737,
#  1.055818,
#  1.055741,
#  1.056054,
#  1.055673,
#  1.055941,
#  1.055864,
#  1.055945,
#  1.055843,
#  1.05605,
#  1.055714,
#  1.056113,
#  1.055827,
#  1.056068,
#  1.055736,
#  1.056133,
#  1.056034,
#  1.056148,
#  1.056073,
#  1.056382,
#  1.056008,
#  1.056273,
#  1.056198,
#  1.056278,
#  1.05618,
#  1.056386,
#  1.05629,
#  1.056495,
#  1.05617,
#  1.05641,
#  1.056339,
#  1.056648,
#  1.056283,
#  1.056546,
#  1.056475,
#  1.056555,
#  1.056459,
#  1.056573,
#  1.0565,
#  1.056803,
#  1.056438,
#  1.056818,
#  1.056483,
#  1.056399,
#  1.056629,
#  1.056353,
#  1.056732,
#  1.056401,
#  1.056659,
#  1.056585,
#  1.056665,
#  1.056567,
#  1.056767,
#  1.05672,
#  1.056811,
#  1.056715,
#  1.056827,
#  1.056755,
#  1.057051,
#  1.056691,
#  1.057063,
#  1.056791,
#  1.057047,
#  1.056977,
#  1.057057,
#  1.056991,
#  1.057084,
#  1.057019,
#  1.056843,
#  1.056751,
#  1.056952,
#  1.056907,
#  1.056999,
#  1.056936,
#  1.057028,
#  1.056935,
#  1.057134,
#  1.05707,
#  1.057161,
#  1.057098,
#  1.056927,
#  1.056837,
#  1.056949,
#  1.05688,
#  1.057176,
#  1.056825,
#  1.057079,
#  1.057011,
#  1.05709,
#  1.057023,
#  1.057102,
#  1.057012,
#  1.05721,
#  1.057166,
#  1.057258,
#  1.057196,
#  1.057287,
#  1.057226,
#  1.057317,
#  1.057227,
#  1.057421,
#  1.057359,
#  1.057192,
#  1.056887,
#  1.057122,
#  1.057489,
#  1.057168,
#  1.057108,
#  1.0572,
#  1.057112,
#  1.057223,
#  1.057157,
#  1.057451,
#  1.057125,
#  1.057352,
#  1.057046,
#  1.057418,
#  1.05716,
#  1.057413,
#  1.057348,
#  1.057427,
#  1.057368,
#  1.05746,
#  1.057373,
#  1.057568,
#  1.057508,
#  1.0576,
#  1.05754,
#  1.057631,
#  1.057572,
#  1.057663,
#  1.057576,
#  1.057686,
#  1.05762,
#  1.057909,
#  1.057568,
#  1.057933,
#  1.057628,
#  1.057853,
#  1.057558,
#  1.057919,
#  1.057667,
#  1.057916,
#  1.057851,
#  1.05793,
#  1.057866,
#  1.058153,
#  1.057819,
#  1.058176,
#  1.057883,
#  1.058106,
#  1.058068,
#  1.0579,
#  1.058144,
#  1.05808,
#  1.058159,
#  1.058073,
#  1.058266,
#  1.058209,
#  1.058299,
#  1.058242,
#  1.058333,
#  1.058247,
#  1.058438,
#  1.05838,
#  1.05847,
#  1.058413,
#  1.058254,
#  1.058007,
#  1.058444,
#  1.058122,
#  1.058084,
#  1.058174,
#  1.05812,
#  1.05821,
#  1.058156,
#  1.058246,
#  1.058164,
#  1.058273,
#  1.058214,
#  1.058503,
#  1.058444,
#  1.058522,
#  1.058441,
#  1.058632,
#  1.058577,
#  1.058667,
#  1.058612,
#  1.058455,
#  1.058418,
#  1.058508,
#  1.058428,
#  1.058536,
#  1.058477,
#  1.058761,
#  1.058441,
#  1.058688,
#  1.058628,
#  1.058706,
#  1.058626,
#  1.058816,
#  1.058762,
#  1.058851,
#  1.058798,
#  1.058887,
#  1.058834,
#  1.05868,
#  1.058306]

# %%
plt.figure(figsize=(10,8))

plt.plot(range(1,len(xgb_reg.evals_result()['validation_0']['rmse'])+1), 
         xgb_reg.evals_result()['validation_0']['rmse'])
plt.scatter([range(1,len(xgb_reg.evals_result()['validation_0']['rmse'])+1)[np.argmin(xgb_reg.evals_result()['validation_0']['rmse'])]], 
            [np.min(xgb_reg.evals_result()['validation_0']['rmse'])], c='k')
plt.text(range(1,len(xgb_reg.evals_result()['validation_0']['rmse'])+1)[np.argmin(xgb_reg.evals_result()['validation_0']['rmse'])], 
         np.min(xgb_reg.evals_result()['validation_0']['rmse'])-.05, "Min.", fontsize=14)

plt.title("Validation Error", fontsize=20)
plt.xlabel("Number of Weak Learners", fontsize=16)
plt.ylabel("RMSE", fontsize=16)

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.show()

# %% [markdown]
# Further, `XGBoost` allows us to implement early stopping without having to write our own code to do so. We just have to include an `early_stopping_rounds` argument during the `fit` step.

# %%
## same xgb_reg as before
xgb_reg = xgboost.XGBRegressor(n_estimators = 500,
                                  max_depth = 1,
                                  learning_rate = .1)


## Now show off early_stopping_rounds with eval_set
xgb_reg.fit(X.reshape(-1,1), y,
                   early_stopping_rounds = 10,
                   eval_set=[(X_val.reshape(-1,1), y_val)])
# Out:
# [0]	validation_0-rmse:1.77179
# [1]	validation_0-rmse:1.71867
# [2]	validation_0-rmse:1.66455
# [3]	validation_0-rmse:1.62196
# [4]	validation_0-rmse:1.57879
# [5]	validation_0-rmse:1.54459
# [6]	validation_0-rmse:1.50800
# [7]	validation_0-rmse:1.48094
# [8]	validation_0-rmse:1.45219
# [9]	validation_0-rmse:1.43014
# [10]	validation_0-rmse:1.40503
# [11]	validation_0-rmse:1.38715
# [12]	validation_0-rmse:1.36746
# [13]	validation_0-rmse:1.35279
# [14]	validation_0-rmse:1.33496
# [15]	validation_0-rmse:1.32275
# [16]	validation_0-rmse:1.30585
# [17]	validation_0-rmse:1.29586
# [18]	validation_0-rmse:1.28377
# [19]	validation_0-rmse:1.27520
# [20]	validation_0-rmse:1.26043
# [21]	validation_0-rmse:1.25324
# [22]	validation_0-rmse:1.24013
# [23]	validation_0-rmse:1.23483
# [24]	validation_0-rmse:1.22628
# [25]	validation_0-rmse:1.22111
# [26]	validation_0-rmse:1.21005
# [27]	validation_0-rmse:1.20554
# [28]	validation_0-rmse:1.19881
# [29]	validation_0-rmse:1.19473
# [30]	validation_0-rmse:1.18531
# [31]	validation_0-rmse:1.18161
# [32]	validation_0-rmse:1.17501
# [33]	validation_0-rmse:1.17163
# [34]	validation_0-rmse:1.16668
# [35]	validation_0-rmse:1.16390
# [36]	validation_0-rmse:1.15812
# [37]	validation_0-rmse:1.15539
# [38]	validation_0-rmse:1.15130
# [39]	validation_0-rmse:1.15047
# [40]	validation_0-rmse:1.14517
# [41]	validation_0-rmse:1.14319
# [42]	validation_0-rmse:1.13733
# [43]	validation_0-rmse:1.13670
# [44]	validation_0-rmse:1.13227
# [45]	validation_0-rmse:1.13183
# [46]	validation_0-rmse:1.12879
# [47]	validation_0-rmse:1.12749
# [48]	validation_0-rmse:1.12342
# [49]	validation_0-rmse:1.12057
# [50]	validation_0-rmse:1.12048
# [51]	validation_0-rmse:1.11666
# [52]	validation_0-rmse:1.11667
# [53]	validation_0-rmse:1.11315
# [54]	validation_0-rmse:1.11216
# [55]	validation_0-rmse:1.10986
# [56]	validation_0-rmse:1.10998
# [57]	validation_0-rmse:1.10685
# [58]	validation_0-rmse:1.10704
# [59]	validation_0-rmse:1.10414
# [60]	validation_0-rmse:1.10213
# [61]	validation_0-rmse:1.09904
# [62]	validation_0-rmse:1.09929
# [63]	validation_0-rmse:1.09675
# [64]	validation_0-rmse:1.09705
# [65]	validation_0-rmse:1.09542
# [66]	validation_0-rmse:1.09377
# [67]	validation_0-rmse:1.09148
# [68]	validation_0-rmse:1.09178
# [69]	validation_0-rmse:1.08970
# [70]	validation_0-rmse:1.09004
# [71]	validation_0-rmse:1.08788
# [72]	validation_0-rmse:1.08751
# [73]	validation_0-rmse:1.08791
# [74]	validation_0-rmse:1.08577
# [75]	validation_0-rmse:1.08454
# [76]	validation_0-rmse:1.08494
# [77]	validation_0-rmse:1.08302
# [78]	validation_0-rmse:1.08175
# [79]	validation_0-rmse:1.08218
# [80]	validation_0-rmse:1.08032
# [81]	validation_0-rmse:1.08080
# [82]	validation_0-rmse:1.07919
# [83]	validation_0-rmse:1.07813
# [84]	validation_0-rmse:1.07715
# [85]	validation_0-rmse:1.07760
# [86]	validation_0-rmse:1.07593
# [87]	validation_0-rmse:1.07640
# [88]	validation_0-rmse:1.07482
# [89]	validation_0-rmse:1.07529
# [90]	validation_0-rmse:1.07379
# [91]	validation_0-rmse:1.07372
# [92]	validation_0-rmse:1.07217
# [93]	validation_0-rmse:1.07264
# [94]	validation_0-rmse:1.07126
# [95]	validation_0-rmse:1.07044
# [96]	validation_0-rmse:1.07092
# [97]	validation_0-rmse:1.06958
# [98]	validation_0-rmse:1.07005
# [99]	validation_0-rmse:1.06879
# [100]	validation_0-rmse:1.06813
# [101]	validation_0-rmse:1.06860
# [102]	validation_0-rmse:1.06746
# [103]	validation_0-rmse:1.06677
# [104]	validation_0-rmse:1.06710
# [105]	validation_0-rmse:1.06758
# [106]	validation_0-rmse:1.06645
# [107]	validation_0-rmse:1.06643
# [108]	validation_0-rmse:1.06583
# [109]	validation_0-rmse:1.06618
# [110]	validation_0-rmse:1.06516
# [111]	validation_0-rmse:1.06563
# [112]	validation_0-rmse:1.06597
# [113]	validation_0-rmse:1.06542
# [114]	validation_0-rmse:1.06505
# [115]	validation_0-rmse:1.06410
# [116]	validation_0-rmse:1.06456
# [117]	validation_0-rmse:1.06491
# [118]	validation_0-rmse:1.06398
# [119]	validation_0-rmse:1.06402
# [120]	validation_0-rmse:1.06448
# [121]	validation_0-rmse:1.06398
# [122]	validation_0-rmse:1.06432
# [123]	validation_0-rmse:1.06344
# [124]	validation_0-rmse:1.06390
# [125]	validation_0-rmse:1.06360
# [126]	validation_0-rmse:1.06275
# [127]	validation_0-rmse:1.06309
# [128]	validation_0-rmse:1.06265
# [129]	validation_0-rmse:1.06309
# [130]	validation_0-rmse:1.06231
# [131]	validation_0-rmse:1.06275
# [132]	validation_0-rmse:1.06308
# [133]	validation_0-rmse:1.06267
# [134]	validation_0-rmse:1.06241
# [135]	validation_0-rmse:1.06274
# [136]	validation_0-rmse:1.06207
# [137]	validation_0-rmse:1.06250
# [138]	validation_0-rmse:1.06167
# [139]	validation_0-rmse:1.06128
# [140]	validation_0-rmse:1.06160
# [141]	validation_0-rmse:1.06090
# [142]	validation_0-rmse:1.06133
# [143]	validation_0-rmse:1.06080
# [144]	validation_0-rmse:1.06059
# [145]	validation_0-rmse:1.06090
# [146]	validation_0-rmse:1.06029
# [147]	validation_0-rmse:1.06060
# [148]	validation_0-rmse:1.06001
# [149]	validation_0-rmse:1.06042
# [150]	validation_0-rmse:1.05972
# [151]	validation_0-rmse:1.06003
# [152]	validation_0-rmse:1.05946
# [153]	validation_0-rmse:1.05977
# [154]	validation_0-rmse:1.05989
# [155]	validation_0-rmse:1.05924
# [156]	validation_0-rmse:1.05964
# [157]	validation_0-rmse:1.05901
# [158]	validation_0-rmse:1.05847
# [159]	validation_0-rmse:1.05878
# [160]	validation_0-rmse:1.05860
# [161]	validation_0-rmse:1.05899
# [162]	validation_0-rmse:1.05841
# [163]	validation_0-rmse:1.05788
# [164]	validation_0-rmse:1.05819
# [165]	validation_0-rmse:1.05857
# [166]	validation_0-rmse:1.05805
# [167]	validation_0-rmse:1.05836
# [168]	validation_0-rmse:1.05781
# [169]	validation_0-rmse:1.05819
# [170]	validation_0-rmse:1.05769
# [171]	validation_0-rmse:1.05799
# [172]	validation_0-rmse:1.05747
# [173]	validation_0-rmse:1.05731
# [174]	validation_0-rmse:1.05760
# [175]	validation_0-rmse:1.05708
# [176]	validation_0-rmse:1.05737
# [177]	validation_0-rmse:1.05687
# [178]	validation_0-rmse:1.05724
# [179]	validation_0-rmse:1.05671
# [180]	validation_0-rmse:1.05700
# [181]	validation_0-rmse:1.05652
# [182]	validation_0-rmse:1.05680
# [183]	validation_0-rmse:1.05634
# [184]	validation_0-rmse:1.05670
# [185]	validation_0-rmse:1.05698
# [186]	validation_0-rmse:1.05652
# [187]	validation_0-rmse:1.05661
# [188]	validation_0-rmse:1.05610
# [189]	validation_0-rmse:1.05638
# [190]	validation_0-rmse:1.05594
# [191]	validation_0-rmse:1.05622
# [192]	validation_0-rmse:1.05657
# [193]	validation_0-rmse:1.05607
# [194]	validation_0-rmse:1.05594
# [195]	validation_0-rmse:1.05551
# [196]	validation_0-rmse:1.05579
# [197]	validation_0-rmse:1.05537
# [198]	validation_0-rmse:1.05565
# [199]	validation_0-rmse:1.05599
# [200]	validation_0-rmse:1.05535
# [201]	validation_0-rmse:1.05495
# [202]	validation_0-rmse:1.05522
# [203]	validation_0-rmse:1.05533
# [204]	validation_0-rmse:1.05519
# [205]	validation_0-rmse:1.05552
# [206]	validation_0-rmse:1.05505
# [207]	validation_0-rmse:1.05494
# [208]	validation_0-rmse:1.05481
# [209]	validation_0-rmse:1.05504
# [210]	validation_0-rmse:1.05492
# [211]	validation_0-rmse:1.05504
# [212]	validation_0-rmse:1.05530
# [213]	validation_0-rmse:1.05488
# [214]	validation_0-rmse:1.05476
# [215]	validation_0-rmse:1.05499
# [216]	validation_0-rmse:1.05525
# [217]	validation_0-rmse:1.05485
# [218]	validation_0-rmse:1.05473
# [219]	validation_0-rmse:1.05485
# [220]	validation_0-rmse:1.05442
# [221]	validation_0-rmse:1.05476
# [222]	validation_0-rmse:1.05463
# [223]	validation_0-rmse:1.05486
# [224]	validation_0-rmse:1.05474
# [225]	validation_0-rmse:1.05496
# [226]	validation_0-rmse:1.05485
# [227]	validation_0-rmse:1.05496
# [228]	validation_0-rmse:1.05522
# [229]	validation_0-rmse:1.05483
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=1, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=500, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
plt.figure(figsize=(10,8))

plt.plot(range(1,len(xgb_reg.evals_result()['validation_0']['rmse'])+1), 
         xgb_reg.evals_result()['validation_0']['rmse'])
plt.scatter([range(1,len(xgb_reg.evals_result()['validation_0']['rmse'])+1)[np.argmin(xgb_reg.evals_result()['validation_0']['rmse'])]], 
            [np.min(xgb_reg.evals_result()['validation_0']['rmse'])], c='k')
plt.text(range(1,len(xgb_reg.evals_result()['validation_0']['rmse'])+1)[np.argmin(xgb_reg.evals_result()['validation_0']['rmse'])], 
         np.min(xgb_reg.evals_result()['validation_0']['rmse'])-.05, "Min.", fontsize=14)

plt.title("Validation Error", fontsize=20)
plt.xlabel("Number of Weak Learners", fontsize=16)
plt.ylabel("RMSE", fontsize=16)

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.show()

# %%
xgb_reg = xgboost.XGBRegressor(n_estimators = 220,
                                  max_depth = 1,
                                  learning_rate = .1)
xgb_reg.fit(X.reshape(-1,1), y)

plt.figure(figsize=(10,8))

plt.scatter(X,y,label='Training Points')
plt.plot(X, xgb_reg.predict(X.reshape(-1,1)), 'k',label="Prediction")
plt.legend(fontsize=14)
plt.xlabel("$X$", fontsize=16)
plt.ylabel("$y$", fontsize=16)

plt.show()

# %% [markdown]
# Here we have scratched the surface of what `XGBoost` can do. To learn more about the package check out the gradient boosting `Practice Problems` as well as the `XGBoost` documentation, <a href="https://xgboost.readthedocs.io/en/latest/index.html">https://xgboost.readthedocs.io/en/latest/index.html</a>.

# %% [markdown]
# --------------------------
#
# This notebook was written for the Erd&#337;s Institute C&#337;de Data Science Boot Camp by Matthew Osborne, Ph. D., 2022.
#
# Any potential redistributors must seek and receive permission from Matthew Tyler Osborne, Ph.D. prior to redistribution. Redistribution of the material contained in this repository is conditional on acknowledgement of Matthew Tyler Osborne, Ph.D.'s original authorship and sponsorship of the Erdős Institute as subject to the license (see License.md)
